# %% [markdown]
# # EDA - Exploratory Data Analysis

# %% [markdown]
# # Step 1 : Data Ingestion-

# %%
path=r"C:\Users\Admin\Desktop\Rashmi_DA\Datasets\laptopPrice.csv"

# %%
import pandas as pd

# %%
lp=pd.read_csv(path)

# %%
lp
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %% [markdown]
# # Step 2 : Basic Data Quality checks-
#    Check for misssing values ,incorrect datatypes,duplicate rows

# %%
lp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
# ...

# %%
lp.shape
# Out:
# (823, 19)

# %%
lp.columns
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'Price', 'rating',
#        'Number of Ratings', 'Number of Reviews'],
#       dtype='object')

# %%
#missing value
lp.isna().sum()
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
#duplicate Rows
lp.duplicated().sum()
# Out:
# 21

# %% [markdown]
# # There are no missing values in this dataset. However, there 21 duplicated rows

# %% [markdown]
# # Step3: Data Cleaning and Data Transformation:
#     Handle missing values, Duplicated rows and incorrect datatypes
#     Examples:
#    Categorical data:
#     md = lp["xyz"].mode()[0]
#     lp["xyz"].fillna(md,inplace=True)
#     Continuous data:
#     mn = lp["pqr"].mean()
#     lp["pqr"].fillna(mn,inplace=True)

# %%
lp.drop_duplicates(keep="first",inplace=True)

# %%
lp.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Step4: Separate Categorical and Continuous data

# %%
lp.columns
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'Price', 'rating',
#        'Number of Ratings', 'Number of Reviews'],
#       dtype='object')

# %%
lp.dtypes
# Out:
# brand                object
# processor_brand      object
# processor_name       object
# processor_gnrtn      object
# ram_gb               object
# ram_type             object
# ssd                  object
# hdd                  object
# os                   object
# os_bit               object
# graphic_card_gb      object
# weight               object
# warranty             object
# Touchscreen          object
# msoffice             object
# Price                 int64
# rating               object
# Number of Ratings     int64
# Number of Reviews     int64
# dtype: object

# %%
fil1=lp.dtypes=="object"
lp.columns[fil1]
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'rating'],
#       dtype='object')

# %%
fil2=lp.dtypes!="object"
lp.columns[fil2]
# Out:
# Index(['Price', 'Number of Ratings', 'Number of Reviews'], dtype='object')

# %%
fil1 = lp.dtypes=="object"
list(lp.columns[fil1])
# Out:
# ['brand',
#  'processor_brand',
#  'processor_name',
#  'processor_gnrtn',
#  'ram_gb',
#  'ram_type',
#  'ssd',
#  'hdd',
#  'os',
#  'os_bit',
#  'graphic_card_gb',
#  'weight',
#  'warranty',
#  'Touchscreen',
#  'msoffice',
#  'rating']

# %%
cat=list(lp.columns[lp.dtypes=="object"])
con=list(lp.columns[lp.dtypes!="object"])

# %%
cat
# Out:
# ['brand',
#  'processor_brand',
#  'processor_name',
#  'processor_gnrtn',
#  'ram_gb',
#  'ram_type',
#  'ssd',
#  'hdd',
#  'os',
#  'os_bit',
#  'graphic_card_gb',
#  'weight',
#  'warranty',
#  'Touchscreen',
#  'msoffice',
#  'rating']

# %%
con
# Out:
# ['Price', 'Number of Ratings', 'Number of Reviews']

# %% [markdown]
# # Step5: Descriptive Statistics

# %%
lp.describe().T
# Out:
#                    count          mean           std      min      25%  \
# Price              802.0  76625.543641  45232.984422  16990.0  45990.0
# Number of Ratings  802.0    299.844140   1001.784420      0.0      0.0
# Number of Reviews  802.0     36.089776    118.313553      0.0      0.0
#
#                        50%       75%       max
# Price              63990.0  89525.00  441990.0
# Number of Ratings     17.0    140.25   15279.0
# Number of Reviews      2.0     18.00    1947.0

# %%
lp[con].describe().T
# Out:
#                    count          mean           std      min      25%  \
# Price              802.0  76625.543641  45232.984422  16990.0  45990.0
# Number of Ratings  802.0    299.844140   1001.784420      0.0      0.0
# Number of Reviews  802.0     36.089776    118.313553      0.0      0.0
#
#                        50%       75%       max
# Price              63990.0  89525.00  441990.0
# Number of Ratings     17.0    140.25   15279.0
# Number of Reviews      2.0     18.00    1947.0

# %%
lp[cat].describe().T
# Out:
#                 count unique      top freq
# brand             802      8     ASUS  243
# processor_brand   802      3    Intel  594
# processor_name    802     11  Core i5  284
# processor_gnrtn   802      8     11th  328
# ram_gb            802      4     8 GB  404
# ram_type          802      6     DDR4  690
# ssd               802      7   512 GB  389
# hdd               802      4     0 GB  602
# os                802      3  Windows  763
# os_bit            802      2   64-bit  693
# graphic_card_gb   802      5     0 GB  557
# weight            802      3   Casual  509
# warranty          802      4   1 year  498
# Touchscreen       802      2       No  706
# msoffice          802      2       No  522
# rating            802      5  4 stars  437

# %%
lp["rating"]
# Out:
# 0      2 stars
# 1      3 stars
# 2      3 stars
# 3      3 stars
# 4      3 stars
#         ...
# 818    3 stars
# 819    3 stars
# 820    3 stars
# 821    3 stars
# 822    4 stars
# Name: rating, Length: 802, dtype: object

# %%
lp[["rating"]]
# Out:
#       rating
# 0    2 stars
# 1    3 stars
# 2    3 stars
# 3    3 stars
# 4    3 stars
# ..       ...
# 818  3 stars
# 819  3 stars
# 820  3 stars
# 821  3 stars
# 822  4 stars
#
# [802 rows x 1 columns]

# %%
cat
# Out:
# ['brand',
#  'processor_brand',
#  'processor_name',
#  'processor_gnrtn',
#  'ram_gb',
#  'ram_type',
#  'ssd',
#  'hdd',
#  'os',
#  'os_bit',
#  'graphic_card_gb',
#  'weight',
#  'warranty',
#  'Touchscreen',
#  'msoffice',
#  'rating']

# %%
lp[["rating","brand"]]
# Out:
#       rating   brand
# 0    2 stars    ASUS
# 1    3 stars  Lenovo
# 2    3 stars  Lenovo
# 3    3 stars    ASUS
# 4    3 stars    ASUS
# ..       ...     ...
# 818  3 stars    ASUS
# 819  3 stars    ASUS
# 820  3 stars    ASUS
# 821  3 stars    ASUS
# 822  4 stars  Lenovo
#
# [802 rows x 2 columns]

# %% [markdown]
# # Univariate Analysis
#   Categorical : Countplots, barplots
#   Continuous: Histogram

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
cat
# Out:
# ['brand',
#  'processor_brand',
#  'processor_name',
#  'processor_gnrtn',
#  'ram_gb',
#  'ram_type',
#  'ssd',
#  'hdd',
#  'os',
#  'os_bit',
#  'graphic_card_gb',
#  'weight',
#  'warranty',
#  'Touchscreen',
#  'msoffice',
#  'rating']

# %%
# categorial data

# %%
sns.countplot(data=lp,x="brand")
# Out:
# <Axes: xlabel='brand', ylabel='count'>

# %%
plt.figure(figsize=(4,4))
sns.countplot(data=lp,x="brand")
plt.title("countplot for Brand")
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.countplot(data=lp,x="brand",color="purple")
plt.title("countplot of Brand")
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.countplot(data=lp,x="brand",hue="brand")
plt.title("countplot of Brand")
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.countplot(data=lp,x="brand",hue="ram_gb")
plt.title("countplot of Brand ")
plt.show()

# %%
print(cat)
# Out:
# ['brand', 'processor_brand', 'processor_name', 'processor_gnrtn', 'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb', 'weight', 'warranty', 'Touchscreen', 'msoffice', 'rating']

# %%
# to display counplots for multiple categorical columns
for i in cat:
    plt.figure(figsize=(8,8))
    sns.countplot(data=lp,x=i)
    plt.title(f"count plot of {i}")
    plt.show()

# %%
con
# Out:
# ['Price', 'Number of Ratings', 'Number of Reviews']

# %%
# continuous data
plt.figure(figsize=(8,6))
sns.histplot(data=lp,x="Price")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.histplot(data=lp,x="Price",bins=25)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.histplot(data=lp,x="Number of Ratings")
plt.title("histogram of ratings")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.histplot(data=lp,x="Number of Reviews")
plt.title("Histogram of Reviews")
plt.show()

# %%
for i in con:
    plt.figure(figsize=(8,6))
    sns.histplot(data=lp,x=i)
    plt.title(f"histogram of {i}")
    plt.show()

# %%
#color
plt.figure(figsize=(8,6))
sns.histplot(data=lp,x="Price",kde=True,color="red")
plt.title("Histplot of Price")
plt.show()

# %%
for i in con:
    plt.figure(figsize=(8,8))
    sns.histplot(data=lp,x=i,color="purple",kde=True)
    plt.title(f"Histplot of {i}")
    plt.show()

# %%
plt.figure(figsize=(8,6))
sns.histplot(data=lp,x="Price",kde=True,color="red",hue="brand")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.histplot(data=lp,x="Price",kde=True,color="red",hue="ram_gb")
plt.show()

# %% [markdown]
# # Find out avg price of laptops by barnd

# %%
lp.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# ...

# %%
a=lp.groupby(by="brand").mean(numeric_only=True).sort_values(by="Price",ascending=False).round(2)[["Price"]]
a
# Out:
#             Price
# brand
# APPLE   157081.30
# MSI      98713.02
# ASUS     79426.02
# HP       73640.27
# Lenovo   72920.21
# acer     72420.04
# DELL     60788.95
# Avita    56346.50

# %%
a
# Out:
#             Price
# brand
# APPLE   157081.30
# MSI      98713.02
# ASUS     79426.02
# HP       73640.27
# Lenovo   72920.21
# acer     72420.04
# DELL     60788.95
# Avita    56346.50

# %%
a.plot(kind="bar")
# Out:
# <Axes: xlabel='brand'>

# %%
sns.barplot(data=a,x="brand",y="Price",hue="brand")
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# ## Continuous vs Continuous data

# %%
con
# Out:
# ['Price', 'Number of Ratings', 'Number of Reviews']

# %%
sns.scatterplot(data=lp,x="Price",y="Number of Reviews")
plt.show()

# %%
sns.regplot(data=lp,x="Price",y="Number of Ratings",line_kws={"color":"red"})
# Out:
# <Axes: xlabel='Price', ylabel='Number of Ratings'>

# %%
sns.regplot(data=lp,x="Number of Ratings",y="Number of Reviews",line_kws={"color":"purple"})
# Out:
# <Axes: xlabel='Number of Ratings', ylabel='Number of Reviews'>

# %% [markdown]
# ### With the increase of no of ratings, no of reviews will also increase

# %% [markdown]
# #### There is no impact on pricing of laptops when ratings and reviews are considered into picture

# %%
lp.corr(numeric_only=True)
# Out:
#                       Price  Number of Ratings  Number of Reviews
# Price              1.000000          -0.152553          -0.156791
# Number of Ratings -0.152553           1.000000           0.991062
# Number of Reviews -0.156791           0.991062           1.000000

# %%
#clustering => hue: categorical data ex:hue="brand"
sns.scatterplot(data=lp,x="Price",y="Number of Ratings",hue="brand")
# Out:
# <Axes: xlabel='Price', ylabel='Number of Ratings'>

# %%
sns.scatterplot(data=lp,x="Number of Ratings",y="Number of Reviews",hue="brand")
# Out:
# <Axes: xlabel='Number of Ratings', ylabel='Number of Reviews'>

# %%
sns.scatterplot(data=lp,x="Number of Ratings",y="Number of Reviews",hue="os_bit")
# Out:
# <Axes: xlabel='Number of Ratings', ylabel='Number of Reviews'>

# %%
a1=lp.corr(numeric_only=True)
# Out:
#                       Price  Number of Ratings  Number of Reviews
# Price              1.000000          -0.152553          -0.156791
# Number of Ratings -0.152553           1.000000           0.991062
# Number of Reviews -0.156791           0.991062           1.000000

# %%
# Out:
#                       Price  Number of Ratings  Number of Reviews
# Price              1.000000          -0.152553          -0.156791
# Number of Ratings -0.152553           1.000000           0.991062
# Number of Reviews -0.156791           0.991062           1.000000
